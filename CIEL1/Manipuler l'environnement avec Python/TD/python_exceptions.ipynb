# %% [markdown]
# ## TD - The Lord Of The Exceptions
#
# Après un échange avec Gandalf, vous partez à l'aventure pour retrouver les elfes de Fondcombe.
#
# Vous voyagez avec Frodon Sacquet et Sam Gamegie.

# %%
characters = ["Frodon Sacquet", "Sam Gamegie"]

# %% [markdown]
# Voici la liste des exceptions déclarées qui auront lieu tout au long de l'aventure de la communauté de l'anneau.

# %%
class SauronCatchTheRing(BaseException):
    """Sauron a retrouvé l’Anneau. Le Gondor brûle, et nul espoir ne subsiste."""

class LordOfTheRingError(Exception):
    """Quelque chose d'inattendu s'est produit en terre du milieu."""
    pass

class GetOutOfMyFieldError(LordOfTheRingError):
    """Vous tombez sur Merry et Pippin poursuivis par le père Maggotte."""

class OnlyFrodoCanHoldTheRingError(LordOfTheRingError):
    """Frodon Sacquet s'énerve si quelqu'un d'autre porte son anneau."""
    pass

class TooMuchCorruptionError(LordOfTheRingError):
    """Ce personnage est trop corrompu par l’Anneau."""
    pass

class NazgulAttackError(LordOfTheRingError):
    """Les Nazgûls attaquent à Bree ou à Weathertop."""
    pass

class MoriaDoorClosedError(LordOfTheRingError):
    """Gandalf ne connaît pas le mot de passe..."""
    pass

class BalrogAwakenedError(LordOfTheRingError):
    """Le Balrog est réveillé dans la Moria !"""
    pass

# %%
def walk_smoothly(characters):
    if "Peregrin Touque" in characters and "Meriadoc Brandebouc" in characters:
        pass
    else:
        print("Sam: C’est le plus loin que je sois jamais allé de chez moi. Si je fais un pas de plus, ce sera le plus loin que je sois jamais allé.")

walk_smoothly(characters)

# %% [markdown]
# Frodon et Sam marchent tranquillement quand soudain Pippin et Merry croisent leur chemin lors de leur poursuite avec le Père Maggotte.
#
# Adaptez la fonction `walk_smoothly` et levez l'exception `GetOutOfMyFieldError` si Pippin et Merry se trouvent dans l'équipe.

# %%
characters.append(["Peregrin Touque", "Meriadoc Brandebouc"])

try: 
    walk_smoothly(characters)
except LordOfTheRingError:
    raise SauronCatchTheRing

# %% [markdown]
# Modifiez l'appel ci-dessous pour gérer la situation. Une chute dans les bois pourrait vous sortir de là.

# %% [markdown]
# Ecrivez une fonction `get_corruption_level` prenant en argument le nom d'un des 4 personnages et qui donne le niveau de corruption associé au personnage (de 0 à 100) sachant que les hobbits sont les personnages les moins corrompus.

# %%
def get_corruption_level(character):
    pass

# %% [markdown]
# Ecrire une fonction `hold_ring` avec en paramètre le nom du porteur, la fonction doit calculer le niveau de corruption du porteur (en utilisant `get_corruption_level` précédemment définie) :
# - Si le niveau de corruption est trop élevé la fonction doit lever l'exception `TooMuchCorruptionError`
# - Si une autre personne que Frodon Sacquet essaie de porter l'anneau la fonction doit lever l'exception `OnlyFrodoCanHoldTheRingError`
#
# Essayez différents arguments pour obtenir différentes exceptions.

# %%
def hold_ring(character):
    pass

# %% [markdown]
# Vous arrivez à l'auberge de Bree où vous faites la rencontre d'Aragorn.

# %%
characters.append("Grand-Pas")

# %% [markdown]
# La fonction ci-dessous

# %% [markdown]
# En vous inspirant des exceptions déclarées ci-dessus, déclarez une exception `GandalfFellError` avec comme description `Gandalf est tombé dans l’abîme de Khazad-dûm.`

# %%
# Ecrire le code ici
